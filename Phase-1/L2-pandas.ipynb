# %%
import pandas as pd
import numpy as np

# %%
data = {
    "name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "run": [10, 15, 20, 25, 30],
    "avg": [45.5,65.5,345.6,56.5,56.4]
}
df = pd.DataFrame(data, index=["a", "b", "c", "d", "e"])
print(df)
# Out:
#       name  run    avg
# a    Alice   10   45.5
# b      Bob   15   65.5
# c  Charlie   20  345.6
# d    David   25   56.5
# e      Eve   30   56.4

# %%
print(df["run"])
print(df[["avg", "run"]])
print(df.loc[])
# Out:
# a    10
# b    15
# c    20
# d    25
# e    30
# Name: run, dtype: int64
#      avg  run
# a   45.5   10
# b   65.5   15
# c  345.6   20
# d   56.5   25
# e   56.4   30

# %%
df.loc["b":"d"]
# Out:
#       name  run    avg
# b      Bob   15   65.5
# c  Charlie   20  345.6
# d    David   25   56.5

# %%
df.set_index("name")
print(df)
# Out:
#          run    avg
# name
# Alice     10   45.5
# Bob       15   65.5
# Charlie   20  345.6
# David     25   56.5
# Eve       30   56.4
