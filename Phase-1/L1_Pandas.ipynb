# %%
import pandas as pd 
import numpy as np

# %%
data = [1,2,56,4,5]
tup =(1,2,3,4,5)
dirc = {'a':1,'b':2,'c':3}
s = pd.Series(data, index=["A","B","C","D","E"] , name="nummbers", dtype="float")
ts= pd.Series(tup)
ds = pd.Series(dirc)
print(s)
print(ts)
print(ds)
# Out:
# A     1.0
# B     2.0
# C    56.0
# D     4.0
# E     5.0
# Name: nummbers, dtype: float64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(s.index)
print(s.values)
print(s.dtype)
print(s.name)
print(s.shape)
print(s.loc["C"])
print(s.loc["C":"D"])
print(s.loc[s>3])
s.loc["C"]= 100
print(s.loc["C"])
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')
# [ 1.  2. 56.  4.  5.]
# float64
# nummbers
# (5,)
# 56.0
# C    56.0
# D     4.0
# Name: nummbers, dtype: float64
# C    56.0
# D     4.0
# E     5.0
# Name: nummbers, dtype: float64
# 100.0
